# %%
import sys
sys.path.append("knowledge_graph_maker2")
from graph_maker import GraphMaker

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from torch import cuda, bfloat16
import torch
import transformers
from transformers import AutoTokenizer
from time import time
from langchain.llms import HuggingFacePipeline
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter,CharacterTextSplitter
from langchain.schema import Document
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.vectorstores.neo4j_vector import remove_lucene_chars
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA
from langchain.vectorstores import Chroma

# %%
with open('manual_Quantitation_of_Mitral_Regurgitation.txt','r') as f:
    data = f.readlines()

# %%
text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    separators=[". "],
    keep_separator=False,
    chunk_size=500,
    chunk_overlap=50,
    length_function=len,
    is_separator_regex=False,
)
complete_data = text_splitter.create_documents(data)

# %%
graphMaker = GraphMaker(verbose=False)

# %%
graphed = graphMaker.from_documents(complete_data)
# Out:
# ▶︎ GRAPH MAKER LOG - 2024-08-10 09:07:37 - INFO
# Document: 1
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-08-10 09:07:37 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives'}, 'Place', 'Object', 'Concept', 'Organisation', 'Event', 'Condition', 'Disease', 'SymptomsMeasurement Name', 'Observation'] relationships=['Relationship between Any two labeled entities']
# input text: ```
# Quantitation of Mitral Regurgitation
# ```
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-08-10 09:07:42 - INFO
# LLM Response:
# [
#   {
#     "node_1": {"type": "Condition", "id": "Mitral Regurgitation"},
#     "node_2": {"type": "Concept", "id": "Quantitation"},
#     "relationship": "The concept of quantitation is related to the condition of Mitral Regurgitation."
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-08-10 09:07:42 - INFO
# Trying JSON Parsing:
# [
#   {
# ...

# %%
from langchain_community.graphs.graph_document import Node,Relationship,Document,GraphDocument

# %%
graph_documents = []
for i in graphed:
    nodes = []
    relationships = []
    for j in i[0]:
        relationship = Relationship(source=j.node_1,target=j.node_2,type=j.relationship)
        relationships.append(relationship)
        nodes.extend([j.node_1,j.node_2])
    graph_documents.append(GraphDocument(nodes=nodes,relationships=relationships,source=Document(page_content=i[1])))

# %%
graphed[1][0]
# Out:
# [Edge(node_1=Node(id='mitral regurgitation', type='Disease'), node_2=Node(id='Americans', type='Person'), relationship="The disease 'mitral regurgitation' affects the people 'Americans'.", metadata={}, order=1),
#  Edge(node_1=Node(id='mitral regurgitation', type='Disease'), node_2=Node(id='baby boomer population', type='Person'), relationship="The disease 'mitral regurgitation' is expected to increase in prevalence as the 'baby boomer population' ages.", metadata={}, order=1),
#  Edge(node_1=Node(id='mitral regurgitation', type='Disease'), node_2=Node(id='people ≥75 years of age', type='Person'), relationship="The disease 'mitral regurgitation' affects the people '≥75 years of age'.", metadata={}, order=1),
#  Edge(node_1=Node(id='mitral regurgitation', type='Disease'), node_2=Node(id='left ventricular dysfunction', type='Condition'), relationship="The disease 'mitral regurgitation' is secondary to the condition 'left ventricular dysfunction'.", metadata={}, order=1)]

# %%
graphed[1][1]
# Out:
# 'Significant mitral regurgitation (MR) is estimated to afflict >2 million Americans and is anticipated to increase in prevalence as the baby boomer population ages.1 Approximately 10% of people ≥75 years of age have significant MR,1 and these patients have decreased survival regardless of whether MR is caused by a primary leaflet abnormality2 or is secondary to left ventricular (LV) dysfunction.3–7'

# %%
from langchain. graphs import Neo4jGraph
import os
# Neo4j connection details
uri = ""
user = ""
password = ""

# %%
graph = Neo4jGraph(uri, user, password)
graph.add_graph_documents(
  graph_documents, 
  baseEntityLabel=True, 
  include_source=True
)

# %%
os.environ['OPENAI_API_KEY'] = ''
os.environ["NEO4J_URI"] = ""
os.environ["NEO4J_USERNAME"] = ""
os.environ["NEO4J_PASSWORD"] = ""

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Neo4jVector

embeddings_model_name = "sentence-transformers/all-MiniLM-L6-v2"

embeddings = HuggingFaceEmbeddings(model_name=embeddings_model_name)
vector_index = Neo4jVector.from_existing_graph(
    embeddings,
    search_type="hybrid",
    node_label="Document",
    text_node_properties=["text"],
    embedding_node_property="embedding"
)
# Out:
# INFO:datasets:PyTorch version 2.3.0 available.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
graph.query(
    "CREATE FULLTEXT INDEX entity IF NOT EXISTS FOR (e:__Entity__) ON EACH [e.id]")

def generate_full_text_query(input: str) -> str:
    """
    Generate a full-text search query for a given input string.

    This function constructs a query string suitable for a full-text search.
    It processes the input string by splitting it into words and appending a
    similarity threshold (~2 changed characters) to each word, then combines 
    them using the AND operator. Useful for mapping entities from user questions
    to database values, and allows for some misspelings.
    """
    full_text_query = ""
    words = [el for el in remove_lucene_chars(input).split() if el]
    for word in words[:-1]:
        full_text_query += f" {word}~2 AND"
    full_text_query += f" {words[-1]}~2"
    return full_text_query.strip()
    
# Fulltext index query
def structured_retriever(question: str) -> str:
    """
    Collects the neighborhood of entities mentioned
    in the question
    """
    result = ""
    entities = []
    ans = graphMaker.from_text(question)
    #ans = llm_transformer.convert_to_graph_documents([Document(page_content=question)])
    for i in ans:
        entities.append(i.node_1.id)
        entities.append(i.node_2.id)
    print(entities)
    #entities = entity_chain.invoke({"question": question})
    for entity in entities:
        response = graph.query(
            """CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})
            YIELD node,score
            CALL {
              MATCH (node)-[r:!MENTIONS]->(neighbor)
              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output
              UNION
              MATCH (node)<-[r:!MENTIONS]-(neighbor)
              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output
            }
            RETURN output LIMIT 50
            """,
            {"query": generate_full_text_query(entity)},
        )
        result += "\n".join([el['output'] for el in response])
    return result
def retriever(question: str):
    print(f"Search query: {question}")
    structured_data = structured_retriever(question)
    unstructured_data = [el.page_content.replace("text:","") for el in vector_index.similarity_search(question)]
    final_data = f"""Structured data:
{structured_data}
Unstructured data:
{"#Document ". join(unstructured_data)}
    """
    return final_data
# Out:
# INFO:neo4j.notifications:Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE FULLTEXT INDEX entity IF NOT EXISTS FOR (e:__Entity__) ON EACH [e.id]` has no effect.} {description: `FULLTEXT INDEX entity FOR (e:__Entity__) ON EACH [e.id]` already exists.} {position: None} for query: 'CREATE FULLTEXT INDEX entity IF NOT EXISTS FOR (e:__Entity__) ON EACH [e.id]'

# %%
READER_MODEL_NAME = "meta-llama/Meta-Llama-3-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(READER_MODEL_NAME)

# %%
prompt_in_chat_format = [
    {
        "role": "system",
        "content": """Using the information contained in the context,
give a comprehensive answer to the question by using both structured and unstructured data in context
Respond only to the question asked, response should be concise and relevant to the question.
Provide the number of the source document when relevant.
If the answer cannot be deduced from the context, do not give an answer.""",
    },
    {
        "role": "user",
        "content": """Context:
{context}
---
Now here is the question you need to answer.

Question: {question}""",
    },
]
RAG_PROMPT_TEMPLATE = tokenizer.apply_chat_template(
    prompt_in_chat_format, tokenize=False, add_generation_prompt=True
)

# %%
question  = "MR jet meets severe criteria"
ans = retriever(question)
final_prompt = RAG_PROMPT_TEMPLATE.format(context=ans,question=question)
answer = graphMaker._llm_client.invoke(final_prompt)
print(answer.split('\n\n\n')[-1])
# Out:
# Search query: MR jet meets severe criteria
# input text: ```
# MR jet meets severe criteria
# ```
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-08-11 18:14:14 - INFO
# LLM Response:
# [
#   {
#     "node_1": {"type": "Person", "id": "MR jet"},
#     "node_2": {"type": "Condition", "id": "severe criteria"},
#     "relationship": "The MR jet is related to the severe criteria"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-08-11 18:14:14 - INFO
# Trying JSON Parsing:
# [
#   {
#     "node_1": {"type": "Person", "id": "MR jet"},
#     "node_2": {"type": "Condition", "id": "severe criteria"},
#     "relationship": "The MR jet is related to the severe criteria"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-08-11 18:14:14 - INFO
# JSON Parsing Successful!
# ['MR jet', 'severe criteria']
# ...

# %%
question  = "Tell me about vena contracta width"
ans = retriever(question)
final_prompt = RAG_PROMPT_TEMPLATE.format(context=ans,question=question)
answer = graphMaker._llm_client.invoke(final_prompt)
print(answer.split('\n\n\n')[-1])
# Out:
# Search query: Tell me about vena contracta width
# input text: ```
# Tell me about vena contracta width
# ```
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-08-10 09:39:32 - INFO
# LLM Response:
# [
#   {
#     "node_1": {"type": "Concept", "id": "vena contracta width"},
#     "node_2": null,
#     "relationship": "The concept of vena contracta width is being discussed."
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-08-10 09:39:32 - INFO
# Trying JSON Parsing:
# [
#   {
#     "node_1": {"type": "Concept", "id": "vena contracta width"},
#     "node_2": null,
#     "relationship": "The concept of vena contracta width is being discussed."
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-08-10 09:39:32 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER ERROR - 2024-08-10 09:39:32 - INFO
# Failed to parse the Edge:
# ...

# %%
question  = "importance of LV and LA volumes"
ans = retriever(question)
final_prompt = RAG_PROMPT_TEMPLATE.format(context=ans,question=question)
answer = graphMaker._llm_client.invoke(final_prompt)
print(answer.split('\n\n\n')[-1])
# Out:
# Search query: importance of LV and LA volumes
# input text: ```
# importance of LV and LA volumes
# ```
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-08-10 09:39:48 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"type": "Concept", "id": "importance"},
#         "node_2": {"type": "Object", "id": "LV"},
#         "relationship": "The importance is related to the concept of Left Ventricle (LV) volumes."
#     },
#     {
#         "node_1": {"type": "Concept", "id": "importance"},
#         "node_2": {"type": "Object", "id": "LA"},
#         "relationship": "The importance is also related to the concept of Left Atrium (LA) volumes."
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-08-10 09:39:48 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"type": "Concept", "id": "importance"},
#         "node_2": {"type": "Object", "id": "LV"},
# ...

# %%
question  = "criteria for non-severe MR"
ans = retriever(question)
final_prompt = RAG_PROMPT_TEMPLATE.format(context=ans,question=question)
answer = graphMaker._llm_client.invoke(final_prompt)
print(answer.split('\n\n\n')[-1])
# Out:
# Search query: criteria for non-severe MR
# input text: ```
# criteria for non-severe MR
# ```
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/generate "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-08-10 09:40:09 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"type": "Concept", "id": "criteria"},
#         "node_2": {"type": "Condition", "id": "MR"},
#         "relationship": "The criteria are related to the diagnosis or classification of MR."
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-08-10 09:40:09 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"type": "Concept", "id": "criteria"},
#         "node_2": {"type": "Condition", "id": "MR"},
#         "relationship": "The criteria are related to the diagnosis or classification of MR."
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-08-10 09:40:09 - INFO
# JSON Parsing Successful!
#
# ...
